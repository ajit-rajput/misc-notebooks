# %% [markdown]
# ### Getting Topics Using BERTopic and Sentence Transformer Embeddings
#
# Every day, businesses deal with large volumes of unstructured text. From customer interactions in emails to online feedback and reviews. To deal with this large amount of text, we look towards topic modeling. A technique to automatically extract meaning from documents by identifying recurrent topics.
# <br><br>
# BERTopic is a topic modeling technique that leverages BERT embeddings and a class-based TF-IDF to create dense clusters allowing for easily interpretable topics whilst keeping important words in the topic descriptions.
# <br><br><br>
# The main purpose of this article is to give you an in-depth overview of BERTopic’s features and tutorials on how to best apply this for your own projects.

# %%
# !pip3 install numpy==1.21.2

# %% [markdown]
# Restart the Kernel here and check if the notebook is using latest version of numpy.

# %%
import numpy as np
np.__version__
# Out:
# '1.21.2'

# %% [markdown]
# #### Install the packages

# %%
# !pip install bertopic
# !pip install bertopic[visualization]
# !pip install -U sentence-transformers
# Out:
# Collecting bertopic
#   Downloading bertopic-0.9.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 252 kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.20.0 in /opt/conda/lib/python3.7/site-packages (from bertopic) (1.21.2)
# Collecting plotly<4.14.3,>=4.7.0
#   Downloading plotly-4.14.2-py2.py3-none-any.whl (13.2 MB)
#      |████████████████████████████████| 13.2 MB 28.5 MB/s eta 0:00:01
# Collecting hdbscan>=0.8.27
#   Downloading hdbscan-0.8.27.tar.gz (6.4 MB)
#      |████████████████████████████████| 6.4 MB 49.4 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: umap-learn>=0.5.0 in /opt/conda/lib/python3.7/site-packages (from bertopic) (0.5.1)
# Collecting sentence-transformers>=0.4.1
#   Downloading sentence-transformers-2.0.0.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 2.2 MB/s  eta 0:00:01
# Requirement already satisfied: pandas>=1.1.5 in /opt/conda/lib/python3.7/site-packages (from bertopic) (1.2.4)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /opt/conda/lib/python3.7/site-packages (from bertopic) (0.23.2)
# Requirement already satisfied: tqdm>=4.41.1 in /opt/conda/lib/python3.7/site-packages (from bertopic) (4.61.1)
# Requirement already satisfied: joblib>=1.0 in /opt/conda/lib/python3.7/site-packages (from hdbscan>=0.8.27->bertopic) (1.0.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from hdbscan>=0.8.27->bertopic) (1.15.0)
# Requirement already satisfied: scipy>=1.0 in /opt/conda/lib/python3.7/site-packages (from hdbscan>=0.8.27->bertopic) (1.6.3)
# Requirement already satisfied: cython>=0.27 in /opt/conda/lib/python3.7/site-packages (from hdbscan>=0.8.27->bertopic) (0.29.23)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=1.1.5->bertopic) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=1.1.5->bertopic) (2021.1)
# Requirement already satisfied: retrying>=1.3.3 in /opt/conda/lib/python3.7/site-packages (from plotly<4.14.3,>=4.7.0->bertopic) (1.3.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.22.2.post1->bertopic) (2.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /opt/conda/lib/python3.7/site-packages (from sentence-transformers>=0.4.1->bertopic) (4.6.1)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.7/site-packages (from sentence-transformers>=0.4.1->bertopic) (1.7.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.7/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.8.1)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.7/site-packages (from sentence-transformers>=0.4.1->bertopic) (3.2.4)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.7/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.96)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.7/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.0.8)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (0.18.2)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.7/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.7.4.3)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.7/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (0.6)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.4.0)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.0.45)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.0.12)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2021.4.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2.25.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.10.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (20.9)
# Requirement already satisfied: pynndescent>=0.5 in /opt/conda/lib/python3.7/site-packages (from umap-learn>=0.5.0->bertopic) (0.5.3)
# Requirement already satisfied: numba>=0.49 in /opt/conda/lib/python3.7/site-packages (from umap-learn>=0.5.0->bertopic) (0.53.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (49.6.0.post20210108)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /opt/conda/lib/python3.7/site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.36.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (1.26.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (4.0.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (7.1.2)
# Requirement already satisfied: pillow>=4.1.1 in /opt/conda/lib/python3.7/site-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (8.2.0)
# Building wheels for collected packages: hdbscan, sentence-transformers
#   Building wheel for hdbscan (PEP 517) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.27-cp37-cp37m-linux_x86_64.whl size=2411186 sha256=e9754a64dade7d7e9bd625124ea35605b8324a50f6e77491f8ff268244270362
#   Stored in directory: /root/.cache/pip/wheels/73/5f/2f/9a259b84003b84847c259779206acecabb25ab56f1506ee72b
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.0.0-py3-none-any.whl size=126709 sha256=805a03b07eb66a8d0747354e328e9bf6efa5671321e3a3b6980c3e72e0b831d2
#   Stored in directory: /root/.cache/pip/wheels/d1/c1/0f/faafd427f705c4b012274ba60d9a91d75830306811e1355293
# Successfully built hdbscan sentence-transformers
# Installing collected packages: sentence-transformers, plotly, hdbscan, bertopic
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.1.0
#     Uninstalling plotly-5.1.0:
#       Successfully uninstalled plotly-5.1.0
# Successfully installed bertopic-0.9.0 hdbscan-0.8.27 plotly-4.14.2 sentence-transformers-2.0.0
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Requirement already satisfied: bertopic[visualization] in /opt/conda/lib/python3.7/site-packages (0.9.0)
# WARNING: bertopic 0.9.0 does not provide the extra 'visualization'
# Requirement already satisfied: umap-learn>=0.5.0 in /opt/conda/lib/python3.7/site-packages (from bertopic[visualization]) (0.5.1)
# Requirement already satisfied: numpy>=1.20.0 in /opt/conda/lib/python3.7/site-packages (from bertopic[visualization]) (1.21.2)
# Requirement already satisfied: tqdm>=4.41.1 in /opt/conda/lib/python3.7/site-packages (from bertopic[visualization]) (4.61.1)
# Requirement already satisfied: hdbscan>=0.8.27 in /opt/conda/lib/python3.7/site-packages (from bertopic[visualization]) (0.8.27)
# Requirement already satisfied: plotly<4.14.3,>=4.7.0 in /opt/conda/lib/python3.7/site-packages (from bertopic[visualization]) (4.14.2)
# Requirement already satisfied: pandas>=1.1.5 in /opt/conda/lib/python3.7/site-packages (from bertopic[visualization]) (1.2.4)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /opt/conda/lib/python3.7/site-packages (from bertopic[visualization]) (0.23.2)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /opt/conda/lib/python3.7/site-packages (from bertopic[visualization]) (2.0.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from hdbscan>=0.8.27->bertopic[visualization]) (1.15.0)
# Requirement already satisfied: joblib>=1.0 in /opt/conda/lib/python3.7/site-packages (from hdbscan>=0.8.27->bertopic[visualization]) (1.0.1)
# Requirement already satisfied: scipy>=1.0 in /opt/conda/lib/python3.7/site-packages (from hdbscan>=0.8.27->bertopic[visualization]) (1.6.3)
# Requirement already satisfied: cython>=0.27 in /opt/conda/lib/python3.7/site-packages (from hdbscan>=0.8.27->bertopic[visualization]) (0.29.23)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=1.1.5->bertopic[visualization]) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=1.1.5->bertopic[visualization]) (2021.1)
# Requirement already satisfied: retrying>=1.3.3 in /opt/conda/lib/python3.7/site-packages (from plotly<4.14.3,>=4.7.0->bertopic[visualization]) (1.3.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.22.2.post1->bertopic[visualization]) (2.1.0)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.7/site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.1.96)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /opt/conda/lib/python3.7/site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (4.6.1)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.7/site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.8.1)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.7/site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.0.8)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.7/site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (1.7.0)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.7/site-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (3.2.4)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.18.2)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.7/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.7.4.3)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.7/site-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.6)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.0.12)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (20.9)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.10.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2021.4.4)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.0.45)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.4.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.25.1)
# Requirement already satisfied: pynndescent>=0.5 in /opt/conda/lib/python3.7/site-packages (from umap-learn>=0.5.0->bertopic[visualization]) (0.5.3)
# Requirement already satisfied: numba>=0.49 in /opt/conda/lib/python3.7/site-packages (from umap-learn>=0.5.0->bertopic[visualization]) (0.53.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (49.6.0.post20210108)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /opt/conda/lib/python3.7/site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (0.36.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.26.5)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (7.1.2)
# Requirement already satisfied: pillow>=4.1.1 in /opt/conda/lib/python3.7/site-packages (from torchvision->sentence-transformers>=0.4.1->bertopic[visualization]) (8.2.0)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Requirement already satisfied: sentence-transformers in /opt/conda/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.7/site-packages (from sentence-transformers) (3.2.4)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.7/site-packages (from sentence-transformers) (0.1.96)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.7/site-packages (from sentence-transformers) (1.7.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from sentence-transformers) (1.6.3)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /opt/conda/lib/python3.7/site-packages (from sentence-transformers) (4.6.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from sentence-transformers) (1.21.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.7/site-packages (from sentence-transformers) (0.23.2)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.7/site-packages (from sentence-transformers) (0.0.8)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.7/site-packages (from sentence-transformers) (0.8.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from sentence-transformers) (4.61.1)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch>=1.6.0->sentence-transformers) (0.18.2)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.7/site-packages (from torch>=1.6.0->sentence-transformers) (3.7.4.3)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.7/site-packages (from torch>=1.6.0->sentence-transformers) (0.6)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.0.45)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2.25.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.10.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.12)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2021.4.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (20.9)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from nltk->sentence-transformers) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.26.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2021.5.30)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.0.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers) (7.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->sentence-transformers) (2.1.0)
# Requirement already satisfied: pillow>=4.1.1 in /opt/conda/lib/python3.7/site-packages (from torchvision->sentence-transformers) (8.2.0)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %% [markdown]
# Restart the Kernel after the pip install<br>
# numpy has to be the latest, i.e. 1.21.2 is the latest one as of today

# %% [markdown]
# #### Import the libraries

# %%
import pandas as pd
import numpy as np
import string
import regex as re
import nltk 
from nltk.tokenize import TweetTokenizer
from nltk import word_tokenize, FreqDist
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from sentence_transformers import SentenceTransformer

# %% [markdown]
# Read the tweets file and choose only the "tweet" column

# %%
data = pd.read_csv('/kaggle/input/windows11-tweets/Windows11_Tweets.csv')
data = data[data['language']=='en'][['user_id','tweet']]
data.head()
# Out:
#                 user_id                                              tweet
# 0    831944710541418498  Running dev channel Windows 11 and Android 12 ...
# 5             465091440  @Longplay_Games @Thunder_Owl and i'm exacerbat...
# 6            4650866357  @ppy i think it was a windows update, i realiz...
# 9   1339170008866430977  @NathanMcNulty I THOUGHT YOU WERE TALKING ABOU...
# 10  1399778506159054850           @x0_1372 @msuhr10 Windows 11 fixes this.

# %%
# Use the nltk stopword
stopword = nltk.corpus.stopwords.words('english')

## remove the punctuations and only numbers
def remove_punct(text):
    text = re.sub('[^\w\s]', ' ', text)
    text = re.sub('[0-9]+', ' ', text)
    return text.lower()

## remove the hashtags within the tweets
def remove_hashtags(text):
    text  = re.sub(r"#(\w+)", '', text)
    return text

## remove the tweet handles
def remove_tagged_users(text):
    text  = re.sub(r"@(\w+)", '', text)
    return text

## remove the stopwords
def remove_stopwords(text):
    out = " ".join(word for word in text.split() if word not in stopword)
    return out

## remove the URLs embedded within tweets
def remove_urls(text):
    text = re.sub(r"((https?):((//)|(\\\\))+([\w\d:#@%/;$()~_?\+-=\\\.&](#!)?)*)",'', text)
    return text

## remove the emojis from the tweets
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %% [markdown]
# #### Data Pre-processing

# %%
### Clean the data using the preprocessing functions
data['clean_tweet'] = data['tweet'].apply(lambda x: remove_hashtags(x))
data['clean_tweet'] = data['clean_tweet'].apply(lambda x: remove_tagged_users(x))
data['clean_tweet'] = data['clean_tweet'].apply(lambda x: remove_emoji(x))
data['clean_tweet'] = data['clean_tweet'].apply(lambda x: remove_urls(x))
data['clean_tweet'] = data['clean_tweet'].apply(lambda x: remove_punct(x))
data['clean_tweet'] = data['clean_tweet'].apply(lambda x: remove_stopwords(x))

# %%
### find the common words which occur frequently in the tweet.
from collections import Counter
cnt = Counter()
for text in data['clean_tweet'].values:
    for word in text.split():
        cnt[word] += 1
        
cnt.most_common(10)
# Out:
# [('windows', 2392),
#  ('new', 444),
#  ('microsoft', 330),
#  ('apps', 303),
#  ('tool', 180),
#  ('mail', 164),
#  ('snipping', 160),
#  ('feature', 157),
#  ('calculator', 157),
#  ('get', 143)]

# %%
### REmove the top-5 commonly occuring words 

freq = set([w for (w, wc) in cnt.most_common(5)])

def freqwords(text):
    return " ".join([word for word in str(text).split() if word not in freq])

data['clean_tweet'] = data['clean_tweet'].apply(freqwords)

# %%
### remove teh rare words e.g. words appearing only once

freq = pd.Series(' '.join(data['clean_tweet']).split()).value_counts()[-50:] # 10 rare words
freq = list(freq.index)
data['clean_tweet'] = data['clean_tweet'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
data.head()
# Out:
#                 user_id                                              tweet  \
# 0    831944710541418498  Running dev channel Windows 11 and Android 12 ...
# 5             465091440  @Longplay_Games @Thunder_Owl and i'm exacerbat...
# 6            4650866357  @ppy i think it was a windows update, i realiz...
# 9   1339170008866430977  @NathanMcNulty I THOUGHT YOU WERE TALKING ABOU...
# 10  1399778506159054850           @x0_1372 @msuhr10 Windows 11 fixes this.
#
#                                           clean_tweet
# 0   running dev channel android beta simply much p...
# 5   exacerbating issue also dev ring use one set d...
# 6   think update realized update went asleep idk c...
# 9                              thought talking lmaooo
# 10                                              fixes

# %% [markdown]
# #### Lemmatization

# %%
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

wordnet_map = {"N":wordnet.NOUN, "V":wordnet.VERB, "J":wordnet.ADJ, "R":wordnet.ADV} # Pos tag, used Noun, Verb, Adjective and Adverb

# Function for lemmatization using POS tag
def lemmatize_words(text):
    pos_tagged_text = nltk.pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_tagged_text])

# Passing the function to 'text_rare' and store in 'text_lemma'
data['clean_tweet'] = data['clean_tweet'].apply(lemmatize_words)

# %%
data.sample(10)
# Out:
#                   user_id                                              tweet  \
# 795            1469265582  Clean Installation of Windows 11 with legit pr...
# 1559             87537732  Microsoft releases Windows 11 Insider Preview ...
# 4587  1215912913342304257   https://t.co/HrbDfwhPgb  Here are seven of th...
# 1481           2693847595  "Calculator now comes with a dark mode, and of...
# 3121            333969115  Intel released new Wi-Fi and Bluetooth drivers...
# 4896           2325079028  @windowsinsider   Announcing Windows 11 Inside...
# 2792  1313106807707975680  How to Change Touch Keyboard Themes on Windows...
# 326              98160432  @JenMsft @JustinZumwalt My biggest issue is th...
# 2235           1926422736  Will Your Windows 10 Apps Work on Windows 11? ...
# 2330   877514066436214785  Windows 11 now has its first beta release     ...
#
#                                             clean_tweet
# 795                clean installation legit product key
# 1559  release insider preview build snip calculator ...
# 4587  seven best third party start menu include one ...
# 1481  calculator come dark mode course aligns look a...
# 3121       intel release wi fi bluetooth driver support
# 4896  announce insider preview build write amanda la...
# 2792                        change touch keyboard theme
# 326   big issue everything seem least one extra clic...
# 2235                                               work
# 2330  first beta release release first beta availabl...

# %% [markdown]
# ##### Getting Topics Using BERTopic and Sentence Transformer Embeddings

# %%
model = SentenceTransformer('distilbert-base-nli-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.99k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/550 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/265M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/450 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
tweets_data = data['clean_tweet'].tolist()
embeddings = model.encode(tweets_data, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/70 [00:00<?, ?it/s]

# %%
from bertopic import BERTopic

# %% [markdown]
# Under the hood, BERTopic is using sentence-transformers to create embeddings for the documents you pass it. As a default, BERTopic is set to using an English model but is supports any language for which an embedding model exists.
# You can choose the language by simply setting the language parameter in BERTopic

# %%
model2 = BERTopic(language="english")
topics, probabilities = model2.fit_transform(tweets_data,embeddings)

# %% [markdown]
# There are two outputs generated, topics and probabilities. A value in topics simply represents the topic it is assigned to. Probabilities on the other hand demonstrate the likelihood of a document falling into any of the possible topics.
#
# After generating topics and their probabilities, we can access the frequent topics that were generated:<br>

# %%
model2.get_topic_info().head()
# Out:
#    Topic  Count                        Name
# 0     -1    618       -1_want_take_pc_check
# 1      0    152  0_shortage_chip_slow_click
# 2      1    114  1_phase_skype_default_mean
# 3      2    109     2_bad_claim_reduce_trim
# 4      3     97          3_kesy_le_hello_ho

# %% [markdown]
# In the output above, it seems that Topic -1 is the largest. -1 refers to all outliers which do not have a topic assigned. Forcing documents in a topic could lead to poor performance. Thus, we ignore Topic -1.

# %%
model2.get_topic_freq().head()
# Out:
#    Topic  Count
# 0     -1    618
# 1      0    152
# 2      1    114
# 3      2    109
# 4      3     97

# %%
model2.get_topic(1)
# Out:
# [('phase', 0.17401928913748355),
#  ('skype', 0.17263523123817986),
#  ('default', 0.14715061930690299),
#  ('mean', 0.14463153117103902),
#  ('seem', 0.14104493044360628),
#  ('feature', 0.052818618461119876),
#  ('learn', 0.004593108459323202),
#  ('could', 0.003339526249014399),
#  ('forever', 0.0),
#  ('foresee', 0.0),
#  ('foremost', 0.0),
#  ('forehead', 0.0),
#  ('force', 0.0),
#  ('font', 0.0),
#  ('fond', 0.0),
#  ('follow', 0.0),
#  ('followme', 0.0),
#  ('folklore', 0.0),
#  ('folder', 0.0),
#  ('foldable', 0.0),
#  ('fold', 0.0),
#  ('foil', 0.0),
#  ('foi', 0.0),
#  ('focus', 0.0),
#  ('fo', 0.0),
#  ('fn', 0.0),
#  ('flyout', 0.0),
#  ('forget', 0.0),
#  ('forgotten', 0.0),
#  ('forgot', 0.0)]

# %%
model2.visualize_topics()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="610ddb99-33e6-45ae-82eb-7500ef98144f" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("610ddb99-33e6-45ae-82eb-7500ef98144f")) {                    Plotly.newPlot(                        "610ddb99-33e6-45ae-82eb-7500ef98144f",                        [{"customdata": [[7.072090148925781, -8.009109497070312, 0, "shortage | chip | slow | click | pc", 152], [11.564841270446777, 10.096395492553711, 1, "phase | skype | default | mean | seem", 114], [7.137209892272949, -8.074223518371582, 2, "bad | claim | reduce | trim | failure", 109], [-5.806310176849365, 9.104024887084961, 3, "kesy | le | hello | ho | excite", 97], [-3.8099265098571777, 1.6853159666061401, 4, "valve | deck | well | great | ui", 79], [15.058126449584961, 2.707047939300537, 5, "arw | file | view | property | panel", 50], [12.725042343139648, 14.021214485168457, 6, "change | cumulative | accessibility | step | kb", 43], [3.371321201324463, 15.619847297668457, 7, "insider | preview | download | release | build", 42], [2.723674774169922, 14.565768241882324, 8, "updated | calculator | mail | snip | unified", 42], [-3.9531800746917725, 1.913882851600647, 9, "love | girlfriend | nice | aesthetic | enjoy", 37], [-5.850667476654053, 9.856888771057129, 10, "august | june | five | july | release", 36], [-5.886145114898682, 9.218099594116211, 11, "linux | parallel | mac | macos | monterey", 33], [-3.2699084281921387, 1.453987956047058, 12, "icp | great | hard | team | good", 31], [2.3474950790405273, 20.996002197265625, 13, "third | party | dev | antivirus | search", 29], [-5.5778350830078125, 10.353307723999023, 14, "future | redesign | provide | next | preview", 29], [-3.2305240631103516, 1.456895112991333, 15, "android | phone | programme | samsung | mobile", 29], [2.385409355163574, 13.455609321594238, 16, "reveals | calendar | revamp | mail | calculator", 28], [4.039901256561279, -3.989262819290161, 17, "keyboard | touch | theme | mouse | change", 28], [6.240026473999023, 13.667280197143555, 18, "pc | protection | exist | install | security", 27], [15.058117866516113, 2.7069787979125977, 19, "experience | like | interface | enchant | personalization", 26], [2.861449956893921, 14.494733810424805, 20, "tester | updated | calendar | roll | mail", 25], [6.385231018066406, 12.873892784118652, 21, "driver | wireless | bluetooth | intel | gpu", 24], [2.054128408432007, 13.010642051696777, 22, "revamp | snip | news | calculator | mail", 24], [3.0755598545074463, 15.423717498779297, 23, "menu | start | panel | recommend | hide", 23], [-4.0016188621521, -5.50033712387085, 24, "gt | xbox | watch | video | do", 23], [-3.911694049835205, -5.410648822784424, 25, "cpu | remake | old | gaming | remasters", 22], [4.039905071258545, -3.989262342453003, 26, "dark | mode | night | light | theme", 21], [6.313465595245361, 12.993638038635254, 27, "free | cnet | os | download | vpn", 20], [2.436657428741455, 20.907398223876953, 28, "late | sketch | mm | sudoku | aug", 19], [-3.7105793952941895, 1.8315761089324951, 29, "chat | inbox | delivers | light | team", 19], [1.390086054801941, 14.792312622070312, 30, "thisiswin | optimize | edge | experience | testing", 19], [3.1111345291137695, 15.59107780456543, 31, "first | native | roll | debut | start", 19], [2.410003185272217, 13.117555618286133, 32, "version | calculator | mail | diskpart | snip", 19], [1.2920633554458618, 14.75874137878418, 33, "costly | vista | mistake | avoid | successfully", 17], [1.6340354681015015, 14.651741027832031, 34, "revamp | like | snip | build | refresh", 17], [3.446820020675659, 15.565803527832031, 35, "first | set | blog | insider | roll", 17], [6.1156110763549805, 13.24372673034668, 36, "free | download | sell | upgrade | get", 16], [-4.0 ...

# %% [markdown]
# ### Topic Reduction after Training
#
# What if you are left with too many topics after training which took many hours? It would be a shame to have to re-train your model just to experiment with the number of topics.
# <br>
# Fortunately, we can reduce the number of topics after having trained a BERTopic model. Another advantage of doing so is that you can decide the number of topics after knowing how many are actually created:

# %%
new_topics, new_probs = model2.reduce_topics(tweets_data, topics, probabilities, nr_topics=20)

# %%
model2.get_topic_info().head()
# Out:
#    Topic  Count                        Name
# 0     -1    957        -1_pc_update_use_app
# 1      0    152     0_pc_shortage_chip_make
# 2      1    114  1_phase_skype_default_mean
# 3      2    109     2_bad_claim_reduce_good
# 4      3     97        3_hello_well_kesy_le

# %%
model2.get_topic(1)
# Out:
# [('phase', 0.3300204357461385),
#  ('skype', 0.3300169189672654),
#  ('default', 0.30453230703598855),
#  ('mean', 0.300632677779694),
#  ('seem', 0.2984266181726918),
#  ('feature', 0.2102003061902054),
#  ('learn', 0.005973649579753778),
#  ('could', 0.004720067369444974),
#  ('forever', 0.0),
#  ('foresee', 0.0),
#  ('foremost', 0.0),
#  ('forehead', 0.0),
#  ('force', 0.0),
#  ('font', 0.0),
#  ('fond', 0.0),
#  ('follow', 0.0),
#  ('followme', 0.0),
#  ('folklore', 0.0),
#  ('folder', 0.0),
#  ('foldable', 0.0),
#  ('fold', 0.0),
#  ('foil', 0.0),
#  ('foi', 0.0),
#  ('focus', 0.0),
#  ('fo', 0.0),
#  ('fn', 0.0),
#  ('flyout', 0.0),
#  ('forget', 0.0),
#  ('forgotten', 0.0),
#  ('forgot', 0.0)]

# %% [markdown]
# ### Topic Representation
#
# Topics are typically represented by a set of words. In BERTopic, these words are extracted from the documents using a class-based TF-IDF. <br>
#
# At times, you might not be happy with the representation of the topics that were created. This is possible when you selected to have only 1-gram words as representation. Perhaps you want to try out a different n-gram range or you have a custom vectorizer that you want to use.

# %%
# Update topic representation by increasing n-gram range and removing english stopwords
model2.update_topics(tweets_data, new_topics, n_gram_range=(1, 3))

# %%
model2.get_topic_info().head()
# Out:
#    Topic  Count                                               Name
# 0     -1    957                               -1_update_pc_use_app
# 1      0    152                    0_pc_chip shortage_shortage_run
# 2      1    114  1_seem default_default feature_skype seem defa...
# 3      2    109                          2_bad_good bad_good_claim
# 4      3     97                            3_well_hello_le_kesy ho

# %%
model2.get_topic(1)
# Out:
# [('seem default', 0.17170916351625662),
#  ('default feature', 0.17170916351625662),
#  ('skype seem default', 0.17170916351625662),
#  ('seem default feature', 0.17170916351625662),
#  ('skype seem', 0.17170916351625662),
#  ('skype', 0.17122324867172853),
#  ('mean phase', 0.17068883890570938),
#  ('phase', 0.17068883890570938),
#  ('default feature mean', 0.16966419527464766),
#  ('feature mean', 0.16966419527464766),
#  ('feature mean phase', 0.16966419527464766),
#  ('phase skype', 0.1686351940593681),
#  ('mean phase skype', 0.1686351940593681),
#  ('phase skype seem', 0.1686351940593681),
#  ('default', 0.16271594044283963),
#  ('mean', 0.1608785770955346),
#  ('seem', 0.16067773098334964),
#  ('feature', 0.13122590209314922),
#  ('feature skype seem', 0.0038176889846214344),
#  ('feature could mean', 0.0038176889846214344),
#  ('feature could', 0.0038176889846214344),
#  ('mean phase learn', 0.0038176889846214344),
#  ('feature skype', 0.0038176889846214344),
#  ('learn skype seem', 0.0038176889846214344),
#  ('learn skype', 0.0038176889846214344),
#  ('could mean phase', 0.0038176889846214344),
#  ('default feature could', 0.0038176889846214344),
#  ('default feature skype', 0.0038176889846214344),
#  ('phase learn skype', 0.0038176889846214344),
#  ('phase learn', 0.0038176889846214344)]

# %% [markdown]
# For more configurations visit : https://github.com/MaartenGr/BERTopic
